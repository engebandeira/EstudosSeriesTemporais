# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(0,50,0.1)
len(t)
# Out:
# 500

# %% [markdown]
# # Tendência

# %%
a, b = 9, 5.2
trend_linear = a + b * t # Linear trending

a, b = 9, 0.1
trend_exp = a * np.exp(b * t) # Exponential Trending


a, b = 9, 16
trend_log = a + b * np.log(t) # Logarithm Trending


plt.figure()

plt.plot(t, trend_log)

plt.title('Time Series Trending')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-690147233246>:9: RuntimeWarning: divide by zero encountered in log
#   trend_log = a + b * np.log(t) # Logarithm Trending

# %% [markdown]
# # Sazonalidade

# %%
a, b = 12.5 , 15
freq_sin, freq_cos = 6, 12

sasonal_sin = a * np.sin( 2 * np.pi * t / freq_sin)
sasonal_cos = b * np.cos( 2 * np.pi * t / freq_cos)
sasonal = sasonal_sin + sasonal_cos

plt.figure(figsize=(15,6))

plt.plot(t, sasonal_sin, label = 'Sin')
plt.plot(t, sasonal_cos, label = 'Cos')
plt.plot(t, sasonal, label = 'Sin + Cos')
plt.title('Time Series Sasonality')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Série Aditiva

# %%
serie_1 = trend_linear + sasonal_sin

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_linear)

plt.subplot(1,3,2)
plt.plot(t, sasonal_sin)

plt.subplot(1,3,3)
plt.plot(t, serie_1)

plt.tight_layout()
plt.show()

serie_2 = trend_exp + sasonal_sin

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_exp)

plt.subplot(1,3,2)
plt.plot(t, sasonal_sin)

plt.subplot(1,3,3)
plt.plot(t, serie_2)

plt.tight_layout()
plt.show()

serie_3 = trend_log + sasonal_sin

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_log)

plt.subplot(1,3,2)
plt.plot(t, sasonal_sin)

plt.subplot(1,3,3)
plt.plot(t, serie_3)

plt.tight_layout()
plt.show()

# %%
serie_1 = trend_linear + sasonal

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_linear)

plt.subplot(1,3,2)
plt.plot(t, sasonal)

plt.subplot(1,3,3)
plt.plot(t, serie_1)

plt.tight_layout()
plt.show()

serie_2 = trend_exp + sasonal

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_exp)

plt.subplot(1,3,2)
plt.plot(t, sasonal)

plt.subplot(1,3,3)
plt.plot(t, serie_2)

plt.tight_layout()
plt.show()

serie_3 = trend_log + sasonal

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_log)

plt.subplot(1,3,2)
plt.plot(t, sasonal_sin)

plt.subplot(1,3,3)
plt.plot(t, serie_3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Multiplicativo

# %%
serie_1 = trend_linear * sasonal_sin

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_linear)

plt.subplot(1,3,2)
plt.plot(t, sasonal_sin)

plt.subplot(1,3,3)
plt.plot(t, serie_1)

plt.tight_layout()
plt.show()

serie_2 = trend_exp * sasonal_sin

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_exp)

plt.subplot(1,3,2)
plt.plot(t, sasonal_sin)

plt.subplot(1,3,3)
plt.plot(t, serie_2)

plt.tight_layout()
plt.show()

serie_3 = trend_log * sasonal_sin

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_log)

plt.subplot(1,3,2)
plt.plot(t, sasonal_sin)

plt.subplot(1,3,3)
plt.plot(t, serie_3)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-a50db0352ae0>:33: RuntimeWarning: invalid value encountered in multiply
#   serie_3 = trend_log * sasonal_sin

# %%
serie_1 = trend_linear * sasonal

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_linear)

plt.subplot(1,3,2)
plt.plot(t, sasonal)

plt.subplot(1,3,3)
plt.plot(t, serie_1)

plt.tight_layout()
plt.show()

serie_2 = trend_exp * sasonal

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_exp)

plt.subplot(1,3,2)
plt.plot(t, sasonal)

plt.subplot(1,3,3)
plt.plot(t, serie_2)

plt.tight_layout()
plt.show()

serie_3 = trend_log * sasonal

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_log)

plt.subplot(1,3,2)
plt.plot(t, sasonal)

plt.subplot(1,3,3)
plt.plot(t, serie_3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Simulação de Funções Aleatórias

# %%
import random
from statsmodels.graphics.tsaplots import plot_acf

# %%
U = random.uniform(0,1)
print(U)
# Out:
# 0.6668203705742172

# %%
X = random.gauss(0, 1)
print(X)
# Out:
# -0.2512977406296713

# %% [markdown]
# ## Ruído Branco Uniforme

# %%
n = len(t)
Ut = np.zeros((n,1))

for i in range(n):
    Ut[i] = random.uniform(0, 1)

plt.figure(figsize=(18,7))

plt.subplot(1,3,1)
plt.plot(t,Ut)
plt.title('Ruído Branco Uniforme')

plt.subplot(1,3,2)
plt.hist(Ut, bins = 20)
plt.title('Histograma')

ax3 = plt.subplot(1,3,3)
plot_acf(Ut, lags = 30, title='Função de Autocorrelação Amostral', alpha = 0.05, ax = ax3)
plt.show()

# %% [markdown]
# # Ruído Branco Gaussiano

# %%
n = len(t)
Ut = np.zeros((n,1))

for i in range(n):
    Ut[i] = random.gauss(0, 1)

plt.figure(figsize=(18,7))

plt.subplot(1,3,1)
plt.plot(t,Ut)
plt.title('Ruído Branco Uniforme')

plt.subplot(1,3,2)
plt.hist(Ut, bins = 20)
plt.title('Histograma')

ax3 = plt.subplot(1,3,3)
plot_acf(Ut, lags = 30, title='Função de Autocorrelação Amostral', alpha = 0.05, ax = ax3)
plt.show()

# %%
t = np.arange(0,50,0.1)

a, b = 9, 5.2
trend_linear = a + b * t # Linear trending

a, b = 12.5 , 15
freq_sin, freq_cos = 6, 12

sasonal_sin = a * np.sin( 2 * np.pi * t / freq_sin)
sasonal_cos = b * np.cos( 2 * np.pi * t / freq_cos)
sasonal = sasonal_sin + sasonal_cos


n = len(t)
Ut = np.zeros((n,1))

for i in range(n):
    Ut[i] = random.gauss(0, 9.6325)


serie_1 = trend_linear + sasonal + Ut.reshape(1,n)[0]


plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(t, trend_linear)

plt.subplot(1,3,2)
plt.plot(t, sasonal)

plt.subplot(1,3,3)
plt.plot(t, serie_1)

plt.tight_layout()
plt.show()
